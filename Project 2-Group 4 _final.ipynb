# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
plt.style.use('seaborn') #add style for graphs

# %% [markdown]
# ## Data Cleaning and preprocessing
# This section include the steps for data cleaning an preprocessing

# %% [markdown]
# ### Read CSV file

# %%
df = pd.read_csv("Consumer goods.csv")

# %%
df
# Out:
#        Year                Type Product group Producer         Code  Volume  \
# 0      2018  Convenience stores          Meat      J&F   |13/12/38|     420
# 1      2018  Convenience stores          Meat      J&F   |13/13/98|     480
# 2      2018  Convenience stores          Meat      J&F   |13/13/99|     528
# 3      2018  Convenience stores        Coffee      J&F   |13/01/01|    4836
# 4      2018  Convenience stores        Coffee      J&F  |13/01/01a|    5928
# ...     ...                 ...           ...      ...          ...     ...
# 15112  2020        Supermarkets    Vegetables  Monzuro  |102/01/04|    1512
# 15113  2020        Supermarkets    Vegetables  Monzuro  |102/01/05|    1320
# 15114  2020        Supermarkets    Vegetables  Monzuro  |102/01/06|    1572
# 15115  2020        Supermarkets    Vegetables  Monzuro  |102/01/07|    1296
# 15116  2020        Supermarkets    Vegetables  Monzuro  |102/01/08|    1512
#
# ...

# %% [markdown]
# ### Use head to print first 5 rows

# %%
df.head()
# Out:
#    Year                Type Product group Producer         Code  Volume  \
# 0  2018  Convenience stores          Meat      J&F   |13/12/38|     420
# 1  2018  Convenience stores          Meat      J&F   |13/13/98|     480
# 2  2018  Convenience stores          Meat      J&F   |13/13/99|     528
# 3  2018  Convenience stores        Coffee      J&F   |13/01/01|    4836
# 4  2018  Convenience stores        Coffee      J&F  |13/01/01a|    5928
#
#    Cost per unit  Price per unit   Revenues Total Cost  Profit Percent  \
# 0           6.00            8.40  $3,542.00  $2,528.40              29
# 1           6.10            7.40  $3,558.40  $2,947.20              17
# 2           5.40            7.60  $4,019.84  $2,837.12              29
# 3           0.74            0.96  $4,642.56  $3,578.64              23
# 4           0.95            0.99  $5,868.72  $5,631.60               4
#
#      Summary Profits
# 0        Good Profit
# 1  Acceptable Profit
# 2        Good Profit
# ...

# %% [markdown]
# ### Use shape to print shape of dataset

# %%
df.shape### Use head to print first 5 rows
# Out:
# (15117, 12)

# %% [markdown]
# ### Use info to have an overview about the data

# %%
df.info()### Use head to print first 5 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15117 entries, 0 to 15116
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             15117 non-null  object
#  1   Type             15117 non-null  object
#  2   Product group    15117 non-null  object
#  3   Producer         15117 non-null  object
#  4   Code             15117 non-null  object
#  5   Volume           15117 non-null  int64
#  6   Cost per unit    15117 non-null  float64
#  7   Price per unit   15117 non-null  float64
#  8   Revenues         15117 non-null  object
#  9   Total Cost       15117 non-null  object
#  10  Profit Percent   15117 non-null  int64
#  11  Summary Profits  15116 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Use describe to print description about the neumeric columns in dataset

# %%
df.describe()
# Out:
#              Volume  Cost per unit  Price per unit  Profit Percent
# count  15117.000000   15117.000000    15117.000000    15117.000000
# mean    1437.010518       2.393392        3.201063       23.881193
# std     1984.730748       1.414972        1.897611       12.935923
# min       48.000000       0.400000        0.900000      -31.000000
# 25%      396.000000       1.140000        1.330000       15.000000
# 50%      792.000000       2.360000        3.240000       23.000000
# 75%     1452.000000       2.910000        3.920000       33.000000
# max     9600.000000       6.700000        8.700000       66.000000

# %% [markdown]
# ### Check columns data types

# %%
df.dtypes
# Out:
# Year                object
# Type                object
# Product group       object
# Producer            object
# Code                object
# Volume               int64
# Cost per unit      float64
# Price per unit     float64
# Revenues            object
# Total Cost          object
# Profit Percent       int64
# Summary Profits     object
# dtype: object

# %% [markdown]
# ### Make the essential changes to (Revenues and Total cost) columns to change their type

# %%
df['Revenues'] = df["Revenues"].str.replace("$","")
df['Revenues'] = df["Revenues"].str.replace(",","")
df['Total Cost'] = df["Total Cost"].str.replace("$","")
df['Total Cost'] = df["Total Cost"].str.replace(",","")
# Out:
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_11380\361009965.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Revenues'] = df["Revenues"].str.replace("$","")
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_11380\361009965.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Total Cost'] = df["Total Cost"].str.replace("$","")

# %%
df
# Out:
#        Year                Type Product group Producer         Code  Volume  \
# 0      2018  Convenience stores          Meat      J&F   |13/12/38|     420
# 1      2018  Convenience stores          Meat      J&F   |13/13/98|     480
# 2      2018  Convenience stores          Meat      J&F   |13/13/99|     528
# 3      2018  Convenience stores        Coffee      J&F   |13/01/01|    4836
# 4      2018  Convenience stores        Coffee      J&F  |13/01/01a|    5928
# ...     ...                 ...           ...      ...          ...     ...
# 15112  2020        Supermarkets    Vegetables  Monzuro  |102/01/04|    1512
# 15113  2020        Supermarkets    Vegetables  Monzuro  |102/01/05|    1320
# 15114  2020        Supermarkets    Vegetables  Monzuro  |102/01/06|    1572
# 15115  2020        Supermarkets    Vegetables  Monzuro  |102/01/07|    1296
# 15116  2020        Supermarkets    Vegetables  Monzuro  |102/01/08|    1512
#
# ...

# %% [markdown]
# ### Check if there is any null values

# %%
df.isnull().sum()
# Out:
# Year               0
# Type               0
# Product group      0
# Producer           0
# Code               0
# Volume             0
# Cost per unit      0
# Price per unit     0
# Revenues           0
# Total Cost         0
# Profit Percent     0
# Summary Profits    1
# dtype: int64

# %% [markdown]
# ### Drop unnecessary columns

# %%
df.drop(columns=['Code' , 'Volume'] , inplace=True)

# %%
df
# Out:
#        Year                Type Product group Producer  Cost per unit  \
# 0      2018  Convenience stores          Meat      J&F           6.00
# 1      2018  Convenience stores          Meat      J&F           6.10
# 2      2018  Convenience stores          Meat      J&F           5.40
# 3      2018  Convenience stores        Coffee      J&F           0.74
# 4      2018  Convenience stores        Coffee      J&F           0.95
# ...     ...                 ...           ...      ...            ...
# 15112  2020        Supermarkets    Vegetables  Monzuro           0.82
# 15113  2020        Supermarkets    Vegetables  Monzuro           0.83
# 15114  2020        Supermarkets    Vegetables  Monzuro           0.64
# 15115  2020        Supermarkets    Vegetables  Monzuro           0.89
# 15116  2020        Supermarkets    Vegetables  Monzuro           0.81
#
#        Price per unit Revenues Total Cost  Profit Percent    Summary Profits
# ...

# %% [markdown]
# ### Drop the row that contain null value

# %%
df.drop(df.index[(df["Summary Profits"].isnull())] , axis=0 , inplace=True)

# %%
df
# Out:
#        Year                Type Product group Producer  Cost per unit  \
# 0      2018  Convenience stores          Meat      J&F           6.00
# 1      2018  Convenience stores          Meat      J&F           6.10
# 2      2018  Convenience stores          Meat      J&F           5.40
# 3      2018  Convenience stores        Coffee      J&F           0.74
# 4      2018  Convenience stores        Coffee      J&F           0.95
# ...     ...                 ...           ...      ...            ...
# 15112  2020        Supermarkets    Vegetables  Monzuro           0.82
# 15113  2020        Supermarkets    Vegetables  Monzuro           0.83
# 15114  2020        Supermarkets    Vegetables  Monzuro           0.64
# 15115  2020        Supermarkets    Vegetables  Monzuro           0.89
# 15116  2020        Supermarkets    Vegetables  Monzuro           0.81
#
#        Price per unit Revenues Total Cost  Profit Percent    Summary Profits
# ...

# %%
df.isna().sum()
# Out:
# Year               0
# Type               0
# Product group      0
# Producer           0
# Cost per unit      0
# Price per unit     0
# Revenues           0
# Total Cost         0
# Profit Percent     0
# Summary Profits    0
# dtype: int64

# %%
df
# Out:
#        Year                Type Product group Producer  Cost per unit  \
# 0      2018  Convenience stores          Meat      J&F           6.00
# 1      2018  Convenience stores          Meat      J&F           6.10
# 2      2018  Convenience stores          Meat      J&F           5.40
# 3      2018  Convenience stores        Coffee      J&F           0.74
# 4      2018  Convenience stores        Coffee      J&F           0.95
# ...     ...                 ...           ...      ...            ...
# 15112  2020        Supermarkets    Vegetables  Monzuro           0.82
# 15113  2020        Supermarkets    Vegetables  Monzuro           0.83
# 15114  2020        Supermarkets    Vegetables  Monzuro           0.64
# 15115  2020        Supermarkets    Vegetables  Monzuro           0.89
# 15116  2020        Supermarkets    Vegetables  Monzuro           0.81
#
#        Price per unit Revenues Total Cost  Profit Percent    Summary Profits
# ...

# %% [markdown]
# ###  Change the type of (Reveneus and  Total cost) coulmn to  a float64

# %%
df['Revenues'] = df['Revenues'].astype(np.float64)
df['Total Cost'] = df['Total Cost'].astype(np.float64)
df.dtypes
# Out:
# Year                object
# Type                object
# Product group       object
# Producer            object
# Cost per unit      float64
# Price per unit     float64
# Revenues           float64
# Total Cost         float64
# Profit Percent       int64
# Summary Profits     object
# dtype: object

# %%
df
# Out:
#        Year                Type Product group Producer  Cost per unit  \
# 0      2018  Convenience stores          Meat      J&F           6.00
# 1      2018  Convenience stores          Meat      J&F           6.10
# 2      2018  Convenience stores          Meat      J&F           5.40
# 3      2018  Convenience stores        Coffee      J&F           0.74
# 4      2018  Convenience stores        Coffee      J&F           0.95
# ...     ...                 ...           ...      ...            ...
# 15112  2020        Supermarkets    Vegetables  Monzuro           0.82
# 15113  2020        Supermarkets    Vegetables  Monzuro           0.83
# 15114  2020        Supermarkets    Vegetables  Monzuro           0.64
# 15115  2020        Supermarkets    Vegetables  Monzuro           0.89
# 15116  2020        Supermarkets    Vegetables  Monzuro           0.81
#
#        Price per unit  Revenues  Total Cost  Profit Percent    Summary Profits
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Make a bar chart for product group and thier average profit percent

# %%
profit = df.groupby("Product group").mean("Profit Percent" )
plt.figure(figsize=(15 , 7))
plt.bar(profit.index , profit['Profit Percent'] )
plt.title("Product  Group and AVG Profit% "  , fontsize=18)
plt.xlabel('Product Group' , fontsize=12)
plt.ylabel('Profit Percent', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Make a pie chart for producers and thier total revenues

# %%
a = df.groupby("Producer").sum("Revenues")
a=a.sort_values(by='Revenues' , ascending=False)
a.head()
revList = [8721055.6 , 4807947.40 ,3610528.16, 2228108.64 , 1894368.00 , 29159990.8 ]
producer = ['North Cascade' , 'J&F' , 'Delta' , 'Bonduelle' , 'Caffe Italiano' , 'The Rest producers']
plt.figure(figsize=(15 , 7))
plt.pie(revList , labels=producer , shadow=True , explode=[0.3 ,0,0,0,0,0] ,autopct='%1.0f%%' )
plt.title("Producers Revenues" , fontsize=18)
plt.show()

# %% [markdown]
# ### Make a pie chart to show the revenues of each store type

# %%
type_rev=df.groupby('Type').sum()['Revenues']
df['Type'].unique()
# Out:
# array(['Convenience stores', 'Hypermarkets', 'Supermarkets'], dtype=object)

# %%
plt.figure(figsize=(8,6))
plt.pie(type_rev, autopct = '%1.1f%%')
plt.legend(['Convenience stores','Hypermarkets','Supermarkets'],loc=0)
plt.title('Revenues by Store Type', fontsize=18)
plt.show()

# %% [markdown]
# ### Make a bar chart to show the revenues of each product

# %%
products = df['Product group'].unique()
revenuse_by_product = df.groupby(df['Product group']).sum()['Revenues']

plt.figure(figsize=(24,14))
plt.bar(products,
        revenuse_by_product, color='#D35400')
plt.title('Revenues by product',fontsize=30)
plt.xlabel('Product', fontsize=20)
plt.ylabel('Revenues in millions ($)',fontsize=20)
plt.show()

# %% [markdown]
# ### Make a scatter chart to show the relation between price per unit and profit percent

# %%
plt.figure(figsize=(20,10))
plt.scatter(df['Price per unit'][0:2000],df['Profit Percent'][0:2000])
plt.title('Price per unit Vs. Profit Percent', fontsize=20)
plt.xlabel('Cost per unit ($)', fontsize=20)
plt.ylabel('Profit Percent',fontsize=20)
plt.show()

# %% [markdown]
# ### Make a scatter chart to show the relation between price per unit and profit percent

# %%
plt.figure(figsize=(20,10))
cost=df.groupby('Producer').mean().sort_values(by='Total Cost')['Total Cost'].nlargest (5)
plt.plot(cost,  color='black', marker='o', linewidth=3)
plt.title('The five highest-cost producers', fontsize=20)
plt.xlabel('Producers', fontsize=20)
plt.ylabel('Total Cost',fontsize=20)
plt.show()

# %% [markdown]
# ### Make a histogram chart to show the frequent of profit classification

# %%
plt.figure(figsize=(20,10))
plt.hist(df['Summary Profits'],color = "lightblue")
plt.title('The profit classification frequency', fontsize=20)
plt.xlabel('Profit classification', fontsize=20)
plt.ylabel('Frequency',fontsize=20)
plt.show()

# %% [markdown]
# ### Make a bar chart to show the cost for each product

# %%
produ = df['Product group'].unique()
plt.figure(figsize=(24,14))
dst = df.groupby('Product group').mean().sort_values(by='Cost per unit')['Cost per unit']
plt.title('The product cost', fontsize=20)
plt.xlabel('Product', fontsize=20)
plt.ylabel('Cost',fontsize=20)
plt.bar(produ,dst, color='#7eb54e')
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# ### Creat Subplot using the previous

# %%
plt.figure(figsize=(14,30))

#first plot
plt.subplot(4,1,1) #(number of rows, number of columns, number of plot)
plt.bar(profit.index , profit['Profit Percent'] )
plt.title("Product  Group and AVG Profit% ")
plt.xlabel('Product Group' , fontsize=12)
plt.ylabel('Profit Percent', fontsize=12)
plt.xticks(rotation=25)

#second
plt.subplot(4,1,2)
plt.scatter(df['Price per unit'][0:2000],df['Profit Percent'][0:2000])
plt.title('Price per unit Vs. Profit Percent')
plt.xlabel('Cost per unit ($)')
plt.ylabel('Profit Percent')

#third 
plt.subplot(4,1,3)
plt.bar(products,revenuse_by_product, color='#D35400')
plt.title('Revenues by product')
plt.xlabel('Product')
plt.ylabel('Revenues in millions ($)')
plt.xticks(rotation=30)


#fourth 
plt.subplot(4,1,4)
plt.bar(produ,revenuse_by_product, color='#7eb54e')
plt.title('The product cost')
plt.xlabel('Product')
plt.ylabel('Cost')
plt.xticks(rotation=30)



plt.tight_layout(pad=5.0)

plt.show()

# %%
profile = ProfileReport(df)

profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv3.6.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-01-21 20:02:07.702743&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
